# %% [markdown]
# # Catálogo de casos de estudio
#
# Este notebook muestra los casos disponibles y su estado.

# %%
import pandas as pd

casos = pd.DataFrame([
    ['Garver 6 barras','TNEP/GEP','Completo'],
    ['IEEE 14 barras','OPF','Datos AC disponibles'],
    ['IEEE 24 RTS','TNEP','Parcial'],
    ['IEEE 30 barras','OPF','Datos AC disponibles'],
    ['Operación 3 generadores','ED','Completo'],
    ['Hidrotérmico didáctico','Hidrotermico','Completo'],
], columns=['Caso','Uso','Estado'])
display(casos)
