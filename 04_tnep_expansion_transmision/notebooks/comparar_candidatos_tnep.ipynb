# %% [markdown]
# # Comparación de candidatos TNEP
#
# Notebook plantilla para completar con datos del caso seleccionado.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

print('Completar con la ruta del caso de estudio.')
